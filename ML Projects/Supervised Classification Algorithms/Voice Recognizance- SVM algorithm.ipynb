# %%
#import required libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
os.chdir('D:\Simplilearn Goal\Machine Learning course\Demo Datasets\Lesson 6')

# %%
#problem statement
img=plt.imread('voice.png')
plt.figure(figsize=(15,10))
plt.imshow(img)

# %%
df=pd.read_csv('voice-classification.csv')

# %%
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
df.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.084309     3.140168    36.568461     0.895127     0.408216
# std       0.042783     4.240529   134.928661     0.044980     0.177521
# ...

# %%
x=df.drop('label',axis=1)

# %%
y=df['label']

# %%
x.shape,y.shape
# Out:
# ((3168, 20), (3168,))

# %%
#label encoder the target variable
from sklearn.preprocessing import LabelEncoder
Le=LabelEncoder()
y=Le.fit_transform(y)

# %%
x.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-0a97c6eb4f55> in <module>
# ----> 1 x.info()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
x=s.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((2217, 20), (951, 20), (2217,), (951,))

# %%
from sklearn.svm import SVC
s=SVC()
s.fit(x_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
svc_predict=s.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print('accuracy score is',accuracy_score(svc_predict,y_test))
# Out:
# accuracy score is 0.9810725552050473

# %%
print('Confusion matrix is',confusion_matrix(svc_predict,y_test))
# Out:
# Confusion matrix is [[445  11]
#  [  7 488]]

# %%
print('Classifiction Report',classification_report(svc_predict,y_test))
# Out:
# Classifiction Report               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       456
#            1       0.98      0.99      0.98       495
#
#     accuracy                           0.98       951
#    macro avg       0.98      0.98      0.98       951
# weighted avg       0.98      0.98      0.98       951

# %%
x1=df.drop('label',axis=1)

# %%
#apply grid search model and validate
from sklearn.model_selection import GridSearchCV
gs=GridSearchCV(SVC(),param_grid,verbose=2)

# %%
param_grid={'C':[0.1,1,10,100],'gamma':[1,0.1,0.01,0.001]}

# %%
gs.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.2s
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] ................................... C=0.1, gamma=1, total=   0.2s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.2s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.2s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.2s
# ...

# %%
gs_predict=gs.predict(x_test)

# %%
print('accuracy score is',accuracy_score(y_test,gs_predict))
# Out:
# accuracy score is 0.9800210304942166

# %%
print('confusion matrix is',confusion_matrix(y_test,gs_predict))
# Out:
# confusion matrix is [[446   6]
#  [ 13 486]]

# %%
print('classification report is',classification_report(y_test,gs_predict))
# Out:
# classification report is               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       452
#            1       0.99      0.97      0.98       499
#
#     accuracy                           0.98       951
#    macro avg       0.98      0.98      0.98       951
# weighted avg       0.98      0.98      0.98       951
